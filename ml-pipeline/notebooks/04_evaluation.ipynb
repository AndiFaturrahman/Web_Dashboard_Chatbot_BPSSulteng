# %% [markdown]
# # 04. Model Evaluation & Explainability (SHAP & Metrics)
# Evaluasi MAPE, RMSE, dan matriks sensitivitas simulasi kebijakan.

# %%
with open('../models/policy_simulator.json', 'r', encoding='utf-8') as f:
    policy = json.load(f)
print('Baseline:', policy['baseline'])
print('Elasticities:', policy['elasticities'])
