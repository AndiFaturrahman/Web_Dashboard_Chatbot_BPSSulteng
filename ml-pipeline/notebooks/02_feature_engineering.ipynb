# %% [markdown]
# # 02. Feature Engineering & Lag Transformations
# Membangun fitur lag waktu (Lag1), delta perubahan antartahun, dan normalisasi.

# %%
import pandas as pd
df_feat = pd.read_csv('../data/processed/master_features.csv')
print(df_feat.columns.tolist())
print(df_feat[['Wilayah', 'Tahun', 'IPM', 'IPM_Lag1', 'IPM_Delta']].head())
