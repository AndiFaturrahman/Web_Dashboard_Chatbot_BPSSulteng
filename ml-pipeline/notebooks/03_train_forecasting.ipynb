# %% [markdown]
# # 03. Training Machine Learning Models
# Melatih Hybrid Ensemble Forecasting (XGBoost/Polynomial), K-Means Clustering, dan Isolation Forest.

# %%
import json
with open('../models/forecast_models.json', 'r', encoding='utf-8') as f:
    models = json.load(f)
print('Forecasting ready for regions:', len(models.keys()))
